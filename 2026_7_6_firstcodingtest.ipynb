# %% [markdown]
# <a href="https://colab.research.google.com/github/Stella-user/New-Repository/blob/main/2026_7_6_firstcodingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q nilearn

import numpy as np
import matplotlib.pyplot as plt
from nilearn import datasets,plotting
from nilearn.image import mean_img

# Fetch the Haxby dataset
haxby_dataset = datasets.fetch_haxby()

# Path to your fMRI image
fMRI_filename =haxby_dataset.func[0]

view=plotting.view_img(mean_img(fMRI_filename), threshold=None)

view
# Out:
# [fetch_haxby] Dataset directory found: /root/nilearn_data/haxby2001
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:820: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /tmp/ipykernel_2417/1218079238.py:14: UserWarning: The provided image has no sform in its header. Please check the provided file. Results may not be as expected.
#   view=plotting.view_img(mean_img(fMRI_filename), threshold=None)
# /tmp/ipykernel_2417/1218079238.py:14: UserWarning: The provided image has no sform in its header. Please check the provided file. Results may not be as expected.
#   view=plotting.view_img(mean_img(fMRI_filename), threshold=None)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;title&gt;Nilearn - Slice viewer&lt;/title&gt;
#         &lt;link rel=&quot;icon&quot;
#               type=&quot;image/x-icon&quot;
# ...
